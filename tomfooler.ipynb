# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv("./resources/standard_stats_5.csv")

players.head()
# Out:
#    Rk            Player   Nation Pos          Squad Age    Born  MP  Starts  \
# 0   1       Gary Ablett  eng ENG  DF        Everton  29  1965.0  13      13
# 1   2        Tony Adams  eng ENG  DF        Arsenal  28  1966.0  21      21
# 2   3  Jan Åge Fjørtoft   no NOR  FW  Middlesbrough  28  1967.0  28      27
# 3   4   Philippe Albert   be BEL  DF  Newcastle Utd  27  1967.0  23      19
# 4   5     Bradley Allen  eng ENG  FW            QPR  23  1971.0   8       4
#
#     Min  ...  Gls.1  Ast.1  G+A.1  G-PK.1  G+A-PK  Matches  \
# 0  1017  ...   0.00   0.09   0.09    0.00    0.09  Matches
# 1  1890  ...   0.05   0.05   0.10    0.05    0.10  Matches
# 2  2341  ...   0.23   0.15   0.38    0.23    0.38  Matches
# 3  1804  ...   0.20   0.05   0.25    0.20    0.25  Matches
# 4   386  ...   0.23   0.23   0.47    0.23    0.47  Matches
#
#                                          Player Link  Player ID  League  Year
# ...

# %%
counts = players.isna().sum()
print(counts.sort_values())
# Out:
# Rk                 0
# Player Link        0
# League             0
# 90s                0
# Min                0
# Starts             0
# MP                 0
# Year               0
# Squad              0
# Player             0
# Gls                1
# Gls.1              1
# CrdY               1
# CrdR               8
# Player ID         10
# Born              11
# Age               16
# Nation           186
# Pos              213
# PK               302
# G-PK.1           302
# G-PK             302
# PKatt           8555
# Ast.1           8566
# Ast             8566
# G+A             8567
# G+A.1           8567
# G+A-PK          8616
# Matches        16618
# dtype: int64

# %%
players[players['Age'].isnull()]
# Out:
#         Rk               Player  Nation  Pos           Squad  Age    Born  MP  \
# 15864  216         Jérémy Hénin  fr FRA   DF        Le Havre  NaN  1990.0   6
# 16340  199         Jérémy Hénin  fr FRA   DF        Le Havre  NaN  1990.0  25
# 16806  199         Jérémy Hénin  fr FRA   DF        Le Havre  NaN  1990.0  28
# 17298  219         Jérémy Hénin  fr FRA   DF        Le Havre  NaN  1990.0  27
# 25056  559        Cedric Orengo     NaN  NaN         Ajaccio  NaN     NaN   2
# 25057  560    Pierre Moracchini     NaN  NaN         Ajaccio  NaN     NaN   1
# 25602  545          Malick Seck     NaN  NaN            Lens  NaN     NaN   1
# 36570  333      Nikola Petković  rs SRB   DF  Eint Frankfurt  NaN  1996.0   6
# 52840  627      Marco Vittiglio     NaN  NaN         Pescara  NaN     NaN   1
# 53451  611          Elia Bruzzi     NaN  NaN         Livorno  NaN     NaN   1
# 54059  608          Geremy Broh     NaN  NaN           Parma  NaN     NaN   1
# ...

# %%
col_text = """
Gls
Gls.1
CrdY
CrdR
PK
G-PK.1
G-PK
PKatt
Ast.1
Ast
G+A
G+A.1
G+A-PK
"""
cols = []
for col in col_text.split():
    cols.append(col)
print(cols)
# Out:
# ['Gls', 'Gls.1', 'CrdY', 'CrdR', 'PK', 'G-PK.1', 'G-PK', 'PKatt', 'Ast.1', 'Ast', 'G+A', 'G+A.1', 'G+A-PK']
