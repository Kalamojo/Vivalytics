# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv("./resources/2022_players.csv")

players.head()
# Out:
#    Rk           Player   Nation    Pos            Squad  Age  Born  MP  \
# 0   1       Max Aarons  eng ENG     DF     Norwich City   21  2000  34
# 1   2        Che Adams  sct SCO     FW      Southampton   25  1996  30
# 2   3  Rayan Aït Nouri   dz ALG  DF,MF           Wolves   20  2001  23
# 3   4  Kristoffer Ajer   no NOR     DF        Brentford   23  1998  24
# 4   5       Nathan Aké   nl NED     DF  Manchester City   26  1995  14
#
#    Starts   Min  ...  G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  \
# 0      32  2881  ...    0.06  0.03   0.05    0.08    0.03        0.08
# 1      23  2039  ...    0.44  0.31   0.13    0.45    0.31        0.45
# 2      20  1828  ...    0.15  0.03   0.08    0.11    0.03        0.11
# 3      23  1995  ...    0.18  0.04   0.08    0.11    0.04        0.11
# 4      10   923  ...    0.20  0.07   0.06    0.12    0.07        0.12
#
#    Matches                                        Player Link  Player ID  \
# ...

# %%
players[players["Player"] == "Max Aarons"].iloc[0]["image_link"]
# Out:
# 'https://fbref.com/req/202302030/images/headshots/774cf58b_2022.jpg'
